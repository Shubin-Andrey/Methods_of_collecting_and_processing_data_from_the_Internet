# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 94.0.4606
# Get LATEST driver version for 94.0.4606
# Driver [C:\Users\Андрей\.wdm\drivers\chromedriver\win32\94.0.4606.61\chromedriver.exe] found in cache

# %%
driver.get('https://google.ru')

# %%
sbox = driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')

# %%
target_name = 'selenium'

# %%
sbox.send_keys('хабр ' + target_name)
sbox.submit()

# %%
asd = driver.find_elements_by_xpath('//*[@id="rso"]/div/div/div/div//a')

# %%
for el in asd:
    print(el.text, ' -- ', el.get_attribute('href'))
# Out:
# Selenium для Python. Глава 1. Установка - Habr
# https://habr.com › post  --  https://habr.com/ru/post/248559/
#   --  https://www.google.ru/search?q=%D1%85%D0%B0%D0%B1%D1%80+selenium&newwindow=1&source=hp&ei=8L92YZ37GtHKrgSWk7_ADw&iflsig=ALs-wAMAAAAAYXbOAJN7X5XvDZ3e89lGBP5NipNJbwRd#
#   --  https://webcache.googleusercontent.com/search?q=cache:rNBa8-d6-BEJ:https://habr.com/ru/post/248559/+&cd=1&hl=ru&ct=clnk&gl=ru
# selenium webdriver  --  https://www.google.ru/search?newwindow=1&lei=_b92YcyDB6L5qwGL5a6gBg&q=selenium%20webdriver&ved=2ahUKEwiM9o_Y4-XzAhWi_CoKHYuyC2QQsKwBKAB6BAgpEAE
# selenium java  --  https://www.google.ru/search?newwindow=1&lei=_b92YcyDB6L5qwGL5a6gBg&q=selenium%20java&ved=2ahUKEwiM9o_Y4-XzAhWi_CoKHYuyC2QQsKwBKAF6BAgpEAI
# selenium-java maven  --  https://www.google.ru/search?newwindow=1&lei=_b92YcyDB6L5qwGL5a6gBg&q=selenium-java%20maven&ved=2ahUKEwiM9o_Y4-XzAhWi_CoKHYuyC2QQsKwBKAJ6BAgpEAM
# ...

# %%
driver.get('https://rambler.ru')

# %%
sbox = driver.find_element_by_link_text('Войти в почту')

# %%
sbox.click()

# %%
for handle in driver.window_handles:
    print(handle)
# Out:
# CDwindow-25A943D69B7C94421DAA5B53A55BD1AB
# CDwindow-33B90D8E7D81DFAF5B9B2BB0C7040B98

# %%
driver.switch_to_window('CDwindow-33B90D8E7D81DFAF5B9B2BB0C7040B98')
# Out:
# <ipython-input-103-58eed3a1b9c9>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window('CDwindow-33B90D8E7D81DFAF5B9B2BB0C7040B98')

# %%
driver.current_window_handle
# Out:
# 'CDwindow-33B90D8E7D81DFAF5B9B2BB0C7040B98'

# %%
driver.switch_to_window(driver.window_handles[1])
# Out:
# <ipython-input-150-6c6d5ce6602d>:1: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(driver.window_handles[1])

# %%
sbox_log = driver.find_element(By.XPATH, '//*[@id="app"]/div[2]/div[3]/div[2]/div[2]/div[1]/div/div/div[3]/div/div[1]/div[3]/div/a/div[3]')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-151-b6b157e619b2> in <module>
# ----> 1 sbox_log = driver.find_element(By.XPATH, '//*[@id="app"]/div[2]/div[3]/div[2]/div[2]/div[1]/div/div/div[3]/div/div[1]/div[3]/div/a/div[3]')
#
# D:\work\conda\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# D:\work\conda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
for el in sbox_log:
    print(el)

# %%
sbox_log.send_keys('shanld')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-424a6ebad5f3> in <module>
# ----> 1 sbox_log.send_keys('shanld')
#
# AttributeError: 'list' object has no attribute 'send_keys'

# %%
<input class="rui-Input-input -metrika-nokeys" tabindex="0" name="login" type="email" id="login" placeholder="Почта" autocomplete="username" value="">

# %%
from bs4 import BeautifulSoup as bs  
from bs4 import BeautifulStoneSoup    
import bs4

# %%
source_data = driver.page_source

# %%
soup = bs(source_data)

# %%
#print(soup.prettify())
# Out:
# <html lang="ru" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="Создайте электронную почту с надежной защитой от спама и вирусов! Рамблер/почта — удобный и быстрый почтовый ящик, к которому можно подключить несколько адресов и работать со всей входящей почтой через один интерфейс." name="description"/>
#   <meta content="Rambler&amp;Co" name="author"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
#   <link href="https://mail-pda.rambler.ru/" rel="alternate"/>
#   <meta content="Создайте электронную почту с надежной защитой от спама и вирусов! Рамблер/почта — удобный и быстрый почтовый ящик, к которому можно подключить несколько адресов и работать со всей входящей почтой через один интерфейс." property="og:description"/>
# ...

# %% [markdown]
# это совсем не та странцика которую высвечивает хром, из предположений: хром высвечивает страницу авторизации, а эта страница уже авторизованного пользователя, или какая то неведомая страница из глубин рамблеровского нутра.
#
# оставлю все как есть. к тому же в начале произведен парсинг хабра на предмет selenium.
