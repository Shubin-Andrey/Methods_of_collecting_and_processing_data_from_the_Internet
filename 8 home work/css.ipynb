# %%
url = 'https://minzdrav.gov.ru/opendata/7707778246-natskalendarprofilakprivivok2015/data-20170208T1614-structure-20150610T0000.csv'

# %%
from pprint import pprint
import csv
from requests import get
import pandas as pd

# %%
data_frame = pd.read_csv('data-20170208T1614-structure-20150610T0000.csv')

# %%
data_frame
# Out:
#                                              category  \
# 0                                       Новорожденные
# 1                                       Новорожденные
# 2                                                Дети
# 3                                                Дети
# 4                                                Дети
# 5                                                Дети
# 6                                                Дети
# 7                                                Дети
# 8                                                Дети
# 9                                                Дети
# 10                                               Дети
# 11                                               Дети
# 12                                               Дети
# 13                                               Дети
# 14                                               Дети
# 15                                               Дети
# ...

# %%
data_frame = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# D:\work\conda\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# D:\work\conda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# D:\work\conda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %% [markdown]
# как то так)

# %%
with open('data-20170208T1614-structure-20150610T0000.csv', newline='', encoding='utf-8') as csvfile:
    reader = csv.DictReader(csvfile)
    field_names = reader.fieldnames
    print(f"Field Names: {field_names}")
    for row in reader:
        print(f"Row: {row}")
# Out:
# Field Names: ['category', 'age', 'name']
# Row: {'category': 'Новорожденные', 'age': 'Первые 24 часа жизни', 'name': 'Первая вакцинация против вирусного гепатита В'}
# Row: {'category': 'Новорожденные', 'age': 'на 3-7 день жизни', 'name': 'Вакцинация против туберкулеза'}
# Row: {'category': 'Дети', 'age': '1 месяц', 'name': 'Вторая вакцинация против вирусного гепатита В'}
# Row: {'category': 'Дети', 'age': '2 месяца ', 'name': 'Третья вакцинация против вирусного гепатита В (группы риска)'}
# Row: {'category': 'Дети', 'age': '2 месяца ', 'name': 'Первая вакцинация против пневмококковой инфекции'}
# Row: {'category': 'Дети', 'age': '3 месяца', 'name': 'Первая вакцинация против дифтерии,коклюша, столбняка'}
# Row: {'category': 'Дети', 'age': '3 месяца', 'name': 'Первая вакцинация против полиомиелита'}
# Row: {'category': 'Дети', 'age': '3 месяца', 'name': 'Первая вакцинация против гемофильной инфекции (группы риска)'}
# ...
