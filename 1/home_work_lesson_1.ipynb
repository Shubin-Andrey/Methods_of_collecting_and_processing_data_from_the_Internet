# %% [markdown]
# 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.
# 2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
import requests
import json

# %% [markdown]
# **1**
#
# https://www.programmableweb.com/api/github-git-references
# выбрал, точно пригодится

# %%
username = 'я'
token = 'вот прям тут и написал'

# %%
repos = requests.get('https://api.github.com/user/repos', auth=(username, token))

# %%
#repos.json()
# Out:
# [{'id': 379699218,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzNzk2OTkyMTg=',
#   'name': 'MySQLRepo',
#   'full_name': 'Shubin-Andrey/MySQLRepo',
#   'private': False,
#   'owner': {'login': 'Shubin-Andrey',
#    'id': 80539956,
#    'node_id': 'MDQ6VXNlcjgwNTM5OTU2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80539956?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shubin-Andrey',
#    'html_url': 'https://github.com/Shubin-Andrey',
#    'followers_url': 'https://api.github.com/users/Shubin-Andrey/followers',
#    'following_url': 'https://api.github.com/users/Shubin-Andrey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Shubin-Andrey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Shubin-Andrey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Shubin-Andrey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Shubin-Andrey/orgs',
# ...

# %%
my_json = repos.json()

# %%
for repo in repos.json():
    if not repo['private']:
        print(repo['html_url'])
# Out:
# https://github.com/Shubin-Andrey/MySQLRepo
# https://github.com/Shubin-Andrey/project
# https://github.com/Shubin-Andrey/Python-frameworks-for-Data-Science-Numpy-Matplotlib-Scikit-learn
# https://github.com/Shubin-Andrey/pythonHomeWork
# https://github.com/Shubin-Andrey/python_home_work
# https://github.com/Shubin-Andrey/repo-gui
# https://github.com/Shubin-Andrey/repo-prob

# %%
github_api_file_url = 'https://github.com/Shubin-Andrey/python_home_work/pull/4/files'

file_response = requests.get(github_api_file_url, auth=(username, token))

# %%
#file_response.content
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-g92Fp85+/vMzJIfgnpKFYqJ8VrYPHFHaqHRTgF8llOI+TnY0Ey75gxhQtNyXtv67Zv3ub5HufJFDJpvPPMO4UQ==" rel="stylesheet" href="https://github.githubassets.com/assets/light-83dd85a7ce7efef3332487e09e928562.css" /><link crossorigin="anonymous" media="all" integrity="sha512-KWZpEQ6YJCe1nP9i4+VQwGbQNoPXXgeXQpeA9oeM2AGGBQvAjvL+pCHVV7HF8P29jlbcE
# ...

# %%
file_response.encoding
# Out:
# 'utf-8'

# %%
file_str = file_response.content.decode('utf-8')

#print(file_str)
# Out:
# <!DOCTYPE html>
# <html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin>
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
# ...

# %%
print(file_response)
# Out:
# <Response [200]>

# %% [markdown]
# чет я пока не знаю как с этим работать

# %% [markdown]
# **2**

# %%
with open('1.json', 'w') as f:
    json.dump(repos.json(), f)
